# %% [markdown]
# **Importing Libraries**

# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

from sklearn import metrics
from sklearn.cluster import KMeans

# %% [markdown]
# **We have collected air quality dataset from UCI machine learning repository**(https://archive.ics.uci.edu/ml/datasets/Air+Quality).
#
# **Air quality data stored in excel file is loaded using pandas pd.read_excel() function.**

# %%
raw_data = pd.read_excel('/Datasets/AirQualityUCI/AirQualityUCI.xlsx')

# %% [markdown]
# # **Data before preprocessing**
#
#
# *  Dataset consists of around **9357 records and 15 feaetures**. The features of dataset are:
#
#   **Date, Time, CO(GT),	PT08.S1(CO),	NMHC(GT),	C6H6(GT),	PT08.S2(NMHC),	NOx(GT),	PT08.S3(NOx),	NO2(GT),	PT08.S4(NO2),	PT08.S5(O3),	T,	RH,	AH**
# *   Missing values in dataset are filled with -200

# %%
raw_data
# Out:
#            Date      Time  CO(GT)  ...       T         RH        AH
# 0    2004-03-10  18:00:00     2.6  ...  13.600  48.875001  0.757754
# 1    2004-03-10  19:00:00     2.0  ...  13.300  47.700000  0.725487
# 2    2004-03-10  20:00:00     2.2  ...  11.900  53.975000  0.750239
# 3    2004-03-10  21:00:00     2.2  ...  11.000  60.000000  0.786713
# 4    2004-03-10  22:00:00     1.6  ...  11.150  59.575001  0.788794
# ...         ...       ...     ...  ...     ...        ...       ...
# 9352 2005-04-04  10:00:00     3.1  ...  21.850  29.250000  0.756824
# 9353 2005-04-04  11:00:00     2.4  ...  24.325  23.725000  0.711864
# 9354 2005-04-04  12:00:00     2.4  ...  26.900  18.350000  0.640649
# 9355 2005-04-04  13:00:00     2.1  ...  28.325  13.550000  0.513866
# 9356 2005-04-04  14:00:00     2.2  ...  28.500  13.125000  0.502804
#
# [9357 rows x 15 columns]

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# **1.We are replacing missing values(-200) with NaN**.

# %%
raw_data=raw_data.replace(-200, np.nan)

# %%
raw_data
# Out:
#            Date      Time  CO(GT)  ...       T         RH        AH
# 0    2004-03-10  18:00:00     2.6  ...  13.600  48.875001  0.757754
# 1    2004-03-10  19:00:00     2.0  ...  13.300  47.700000  0.725487
# 2    2004-03-10  20:00:00     2.2  ...  11.900  53.975000  0.750239
# 3    2004-03-10  21:00:00     2.2  ...  11.000  60.000000  0.786713
# 4    2004-03-10  22:00:00     1.6  ...  11.150  59.575001  0.788794
# ...         ...       ...     ...  ...     ...        ...       ...
# 9352 2005-04-04  10:00:00     3.1  ...  21.850  29.250000  0.756824
# 9353 2005-04-04  11:00:00     2.4  ...  24.325  23.725000  0.711864
# 9354 2005-04-04  12:00:00     2.4  ...  26.900  18.350000  0.640649
# 9355 2005-04-04  13:00:00     2.1  ...  28.325  13.550000  0.513866
# 9356 2005-04-04  14:00:00     2.2  ...  28.500  13.125000  0.502804
#
# [9357 rows x 15 columns]

# %%
raw_data.describe()
# Out:
#             CO(GT)  PT08.S1(CO)  ...           RH           AH
# count  7674.000000  8991.000000  ...  8991.000000  8991.000000
# mean      2.152750  1099.707856  ...    49.232360     1.025530
# std       1.453252   217.084571  ...    17.316389     0.403813
# min       0.100000   647.250000  ...     9.175000     0.184679
# 25%       1.100000   936.750000  ...    35.812500     0.736769
# 50%       1.800000  1063.000000  ...    49.550000     0.995395
# 75%       2.900000  1231.250000  ...    62.500001     1.313701
# max      11.900000  2039.750000  ...    88.725000     2.231036
#
# [8 rows x 13 columns]

# %% [markdown]
# **2. Imputation of missing values**

# %% [markdown]
# **2.a) Imputation using mean**

# %%
#dropping columns Date and Time
mean_data=raw_data.drop(columns=['Date','Time'])

# %%
#Filling Nans with mean value of the corresponding column
mean_data=mean_data.apply(lambda x: x.fillna(x.mean()),axis=0)

# %%
mean_data
# Out:
#       CO(GT)  PT08.S1(CO)    NMHC(GT)  ...       T         RH        AH
# 0        2.6      1360.00  150.000000  ...  13.600  48.875001  0.757754
# 1        2.0      1292.25  112.000000  ...  13.300  47.700000  0.725487
# 2        2.2      1402.00   88.000000  ...  11.900  53.975000  0.750239
# 3        2.2      1375.50   80.000000  ...  11.000  60.000000  0.786713
# 4        1.6      1272.25   51.000000  ...  11.150  59.575001  0.788794
# ...      ...          ...         ...  ...     ...        ...       ...
# 9352     3.1      1314.25  218.811816  ...  21.850  29.250000  0.756824
# 9353     2.4      1162.50  218.811816  ...  24.325  23.725000  0.711864
# 9354     2.4      1142.00  218.811816  ...  26.900  18.350000  0.640649
# 9355     2.1      1002.50  218.811816  ...  28.325  13.550000  0.513866
# 9356     2.2      1070.75  218.811816  ...  28.500  13.125000  0.502804
#
# [9357 rows x 13 columns]

# %%
#df_data=mean_data[['CO(GT)','NO2(GT)','T','RH']]
#columns=["co", "no2", "o3", "current_temperature", "current_humidity"]
# co: 2nd column, no2: 1st column, 03: 1st column, temperature: 1st column, humidity: RH

# %%
mean_data.describe()
# Out:
#             CO(GT)  PT08.S1(CO)  ...           RH           AH
# count  9357.000000  9357.000000  ...  9357.000000  9357.000000
# mean      2.152750  1099.707856  ...    49.232360     1.025530
# std       1.316068   212.796116  ...    16.974308     0.395836
# min       0.100000   647.250000  ...     9.175000     0.184679
# 25%       1.200000   941.250000  ...    36.550000     0.746115
# 50%       2.152750  1074.500000  ...    49.232360     1.015441
# 75%       2.600000  1221.250000  ...    61.875000     1.296223
# max      11.900000  2039.750000  ...    88.725000     2.231036
#
# [8 rows x 13 columns]

# %%
columns=["PT08.S1(CO)", "NO2(GT)", "PT08.S5(O3)", "T", "RH"]
mean_data = mean_data[columns]
mean_data = mean_data.rename(columns={"PT08.S1(CO)": "co", "NO2(GT)": "no2", "PT08.S5(O3)": "o3", "T": "temperature", "RH": "humidity"})
mean_data
# Out:
#            co    no2       o3  temperature   humidity
# 0     1360.00  113.0  1267.50       13.600  48.875001
# 1     1292.25   92.0   972.25       13.300  47.700000
# 2     1402.00  114.0  1074.00       11.900  53.975000
# 3     1375.50  122.0  1203.25       11.000  60.000000
# 4     1272.25  116.0  1110.00       11.150  59.575001
# ...       ...    ...      ...          ...        ...
# 9352  1314.25  189.8  1728.50       21.850  29.250000
# 9353  1162.50  179.2  1269.00       24.325  23.725000
# 9354  1142.00  174.7  1092.00       26.900  18.350000
# 9355  1002.50  155.7   769.75       28.325  13.550000
# 9356  1070.75  167.7   816.00       28.500  13.125000
#
# [9357 rows x 5 columns]

# %% [markdown]
# **K-means Clustering to label the records**

# %%
data_array=mean_data.to_numpy()

# %%
kmeans = KMeans(init='k-means++', n_clusters=2, n_init=10)
kmeans.fit(data_array)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 986.16063669,   97.99598175,  804.20022617,   18.48519483,
#           48.27709521],
#        [1335.65449561,  144.41019056, 1476.9823739 ,   17.96458608,
#           51.21736296]])

# %%
kmean_l=pd.DataFrame(kmeans.labels_)

# %%
count=0
count1=0
count2=0
for index, row in kmean_l.iterrows():
 if(row[0]==0):
   count=count+1
 elif(row[0]==1):
   count1=count1+1

# %%
print("High =",count)
print("Low =",count1)
# Out:
# High = 6320
# Low = 3037

# %%
mean_data['labels']=kmean_l

# %%
mean_data.head(100)
# Out:
#          co    no2       o3  temperature   humidity  labels
# 0   1360.00  113.0  1267.50       13.600  48.875001       1
# 1   1292.25   92.0   972.25       13.300  47.700000       0
# 2   1402.00  114.0  1074.00       11.900  53.975000       1
# 3   1375.50  122.0  1203.25       11.000  60.000000       1
# 4   1272.25  116.0  1110.00       11.150  59.575001       1
# ..      ...    ...      ...          ...        ...     ...
# 95  1437.75  128.0  1206.25       21.300  30.750000       1
# 96  1477.75  121.0  1262.25       19.650  36.700000       1
# 97  1807.50  157.0  1697.75       18.375  41.725000       1
# 98  1898.00  173.0  1904.75       17.625  46.099999       1
# 99  1559.50  146.0  1648.00       16.650  49.575001       1
#
# [100 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(mean_data)
# Plot the clustered data
# Run local implementation of kmeans
km = KMeans(n_clusters=2, max_iter=100)
km.fit(X_std)
centroids = km.cluster_centers_

# Plot the clustered data
fig, ax = plt.subplots(figsize=(12, 12))
plt.scatter(X_std[km.labels_ == 0, 0], X_std[km.labels_ == 0, 1],
            c='green', label='cluster 1')
plt.scatter(X_std[km.labels_ == 1, 0], X_std[km.labels_ == 1, 1], 
            c='blue', label='cluster 2')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=300,
           c='r', label='centroid')
plt.legend()
#plt.xlim([-2, 2])
#plt.ylim([-2, 2])
plt.xlabel('')
plt.ylabel('')
plt.title('Visualization of clustered data', fontweight='bold')
ax.set_aspect('equal');

# %% [markdown]
# **Correlation Matrix with target label**

# %%
#correlation matrix
corrmat = mean_data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %% [markdown]
# Drop the columns based on correlation of attributes with target label.

# %%
reduced_data=mean_data

# %%
reduced_data.to_csv('CMPE295_Preprocessed_Data_Final.csv',index=False)

# %% [markdown]
# # **Data Visualization**

# %%
#co	no2	o3	temperature	humidity	labels

sns.distplot(reduced_data['co']);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(reduced_data['no2']);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(reduced_data['o3']);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(reduced_data['temperature']);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(reduced_data['humidity']);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#scatterplot
sns.set()
cols = ['co', 'no2', 'o3',
          'temperature', 'humidity']
sns.pairplot(reduced_data[cols], height = 2)
plt.show();

# %%
set1 = ['NO2(GT)']
set2 = ['CO(GT)']

set3 = ['T']
set4 = ['RH']

set5 = ['PT08.S5(O3)']

# %%
raw_data['Index'] = raw_data.Date
raw_data['Index'] = raw_data['Index'].astype(str)

# %%
import datetime
raw_data['Day'] = raw_data['Index'].map( lambda x : datetime.datetime.strptime(x, '%Y-%m-%d').strftime('%A'))
raw_data['Month'] = raw_data['Index'].map( lambda x : datetime.datetime.strptime(x, '%Y-%m-%d').strftime('%m'))
raw_data.head()
# Out:
#         Date      Time  CO(GT)  ...       Index        Day  Month
# 0 2004-03-10  18:00:00     2.6  ...  2004-03-10  Wednesday     03
# 1 2004-03-10  19:00:00     2.0  ...  2004-03-10  Wednesday     03
# 2 2004-03-10  20:00:00     2.2  ...  2004-03-10  Wednesday     03
# 3 2004-03-10  21:00:00     2.2  ...  2004-03-10  Wednesday     03
# 4 2004-03-10  22:00:00     1.6  ...  2004-03-10  Wednesday     03
#
# [5 rows x 18 columns]

# %%
cats = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekly_data = raw_data.groupby('Day').mean()
weekly_data['Day'] = weekly_data.index
weekly_data = weekly_data.reindex(cats)
weekly_data
# Out:
#              CO(GT)  PT08.S1(CO)    NMHC(GT)  ...         RH        AH        Day
# Day                                           ...
# Monday     2.016741  1069.591264  180.110169  ...  47.562593  0.983539     Monday
# Tuesday    2.382267  1116.516588  233.583333  ...  48.598465  1.014063    Tuesday
# Wednesday  2.400787  1126.683187  219.561151  ...  50.076272  1.049379  Wednesday
# Thursday   2.455505  1140.159341  278.800000  ...  50.110544  1.057239   Thursday
# Friday     2.543041  1143.846149  287.302469  ...  50.141902  1.064917     Friday
# Saturday   1.861077  1089.845884  164.563636  ...  48.949636  1.011683   Saturday
# Sunday     1.438069  1016.784232   99.114583  ...  49.274747  1.001677     Sunday
#
# [7 rows x 14 columns]

# %%
sns.barplot(x="Day", y=set1[0], data=weekly_data)

# %%
sns.barplot(x="Day", y=set2[0], data=weekly_data)

# %%
sns.barplot(x="Day", y=set3[0], data=weekly_data)

# %%
sns.barplot(x="Day", y=set4[0], data=weekly_data)

# %%
monthly_data = raw_data.groupby('Month').mean()
monthly_data['Month'] = monthly_data.index
monthly_data
# Out:
#          CO(GT)  PT08.S1(CO)    NMHC(GT)  ...         RH        AH  Month
# Month                                     ...
# 01     2.135059  1110.826257         NaN  ...  56.563995  0.635098     01
# 02     2.096229  1087.574525         NaN  ...  52.080845  0.517457     02
# 03     2.144079  1176.730779  171.604423  ...  50.606418  0.784860     03
# 04     2.142931  1139.384295  256.671937  ...  49.007853  0.887402     04
# 05     1.940034  1076.553539  275.000000  ...  43.540708  0.957332     05
# 06     1.900000  1020.665445         NaN  ...  39.847691  1.275378     06
# 07     1.784946  1046.296321         NaN  ...  33.054767  1.242712     07
# 08     1.280084   980.922542         NaN  ...  42.977446  1.619436     08
# 09     2.164209  1081.451686         NaN  ...  43.988972  1.285426     09
# 10     2.724682  1184.795424         NaN  ...  61.909814  1.464085     10
# 11     2.685420  1132.038773         NaN  ...  59.272222  0.939992     11
# 12     2.751250  1086.978790         NaN  ...  57.821812  0.780547     12
#
# [12 rows x 14 columns]

# %%
sns.barplot(x="Month", y=set1[0], data=monthly_data)

# %%
sns.barplot(x="Month", y=set2[0], data=monthly_data)

# %%
sns.barplot(x="Month", y=set3[0], data=monthly_data)

# %%
sns.barplot(x="Month", y=set4[0], data=monthly_data)

# %%
l[0] = l[0].map({'Moderate': 1, 'High': 0})
# Out:
# "l[0] = l[0].map({'Moderate': 1, 'High': 0})"
